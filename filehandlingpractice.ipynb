# %%
file = open("demo.txt","w")
file.write("Hello everyone")
file.close()

# %%
file = open("demo.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# Hello everyone

# %%
file = open("abc.txt","w")
file.write("welcome class")
file.close()

# %%
file = open("abc.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# welcome class

# %%
try:
    file = open("abc.txt","r")
except FileNotFoundError:
    print("File Doesn't exist")
# Out:
# File Doesn't exist
