# %%
class Car:
    name = "Bmw"
    color = "Yellow"

Car1 = Car
print(Car1.name)
print(Car1.color)
# Out:
# Bmw
# Yellow

# %%
class AboutMe :
    firstname = "Anvitha"
    height = 5.3
    lastname = "Ravula"

AboutMe2 = AboutMe
print(AboutMe2.firstname)
print(AboutMe2.height)
print(AboutMe2.lastname)
# Out:
# Anvitha
# 5.3
# Ravula
