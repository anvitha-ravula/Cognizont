# %%
name="anvitha"
print(name.upper())
# Out:
# ANVITHA

# %%
name="anvitha"
print(name.lower())
# Out:
# anvitha

# %%
s="Hello"
print("Hello" * 5)
# Out:
# HelloHelloHelloHelloHello

# %%
p="I like decoding"
print(p.replace("decoding","coding"))
# Out:
# I like coding

# %%
p="something nothing"
print(p.find("nothing"))
# Out:
# 10

# %%
name=input("Enter the name:")
print("welcome",name)
# Out:
# Enter the name:  anvitha
# welcome  anvitha

# %%
p="python"
print(p[::-1])
# Out:
# nohtyp

# %%
name="anvitha"
def greet():
    print("hello",name)
greet()
# Out:
# hello anvitha

# %%
mine="confidence"
def quality():
    print("self",mine)
quality()
# Out:
# self confidence

# %%
def sub(a,b):
    return a-b
print(sub(50,10))
# Out:
# 40

# %%
def add(a,b,c=0):
    return a+b+c
print(add(10,30))
print(add(10,30,50))
# Out:
# 40
# 90
